# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import pandas as pd
bangalore_df = pd.read_csv("bangalore_df.csv")

# %%
bangalore_df = bangalore_df[bangalore_df['Price (in lakhs)'] < 200]

# %%
bangalore_df
# Out:
#        Index  Price (in lakhs)       City  Floor (Ratio)  Furnishing  facing  \
# 1          1               8.0  bangalore       1.000000           0      -1
# 2          2              70.0  bangalore       0.555556           1      -1
# 3          3              31.4  bangalore       0.500000           0      90
# 4          4             150.0  bangalore       0.750000           1       0
# 5          5              70.0  bangalore       0.000000           2       0
# ...      ...               ...        ...            ...         ...     ...
# 24025  24025              78.0  bangalore       0.000000           0      90
# 24026  24026              88.0  bangalore       0.615385           1      90
# 24027  24027              85.0  bangalore       0.714286           0      90
# 24028  24028              64.0  bangalore       0.600000           0       0
# 24029  24029              86.3  bangalore       0.218750           0      90
#
# ...

# %%
bangalore_df.describe()
# Out:
#               Index  Price (in lakhs)  Floor (Ratio)    Furnishing  \
# count  21365.000000      21365.000000   20469.000000  21365.000000
# mean   12144.056541         82.777028       0.505377      0.621952
# std     6877.415596         23.248442       0.309769      0.585328
# min        1.000000          8.000000       0.000000     -1.000000
# 25%     6224.000000         65.000000       0.250000      0.000000
# 50%    12159.000000         85.000000       0.500000      1.000000
# 75%    18094.000000         90.000000       0.750000      1.000000
# max    24029.000000        199.000000       1.000000      2.000000
#
#              facing      Bathroom       Balcony   Car Parking     Ownership  \
# count  21365.000000  21365.000000  21365.000000  21365.000000  21365.000000
# mean      35.665528      2.252984      0.956284     -0.328107     -0.518933
# std       58.663941      0.527720      1.004091      0.944242      0.510037
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(bangalore_df['Floor (Ratio)'], bangalore_df['Price (in lakhs)'], gridsize=40, cmap='Reds', bins='log')
plt.colorbar(label='log10(N)')
plt.xlabel('Floor (Ratio)')
plt.ylabel('Price')
plt.title('Hexbin Density Plot: Floor (Ratio) vs Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=bangalore_df, x='Floor (Ratio)', bins=20, color='teal', edgecolor='black')
plt.title('Distribution of Floor (Ratio) in Bangalore')
plt.xlabel('Floor (Ratio)')
plt.ylabel('Number of Listings')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(bangalore_df['CurrentFloor'], bangalore_df['Price (in lakhs)'], gridsize=40, cmap='Reds', bins='log')
plt.colorbar(label='log10(N)')
plt.xlabel('CurrentFloor')
plt.ylabel('Price')
plt.title('Hexbin Density Plot: Floor (Ratio) vs Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=bangalore_df, x='CurrentFloor', bins=range(0, int(bangalore_df['CurrentFloor'].max()) + 2), color='mediumseagreen', edgecolor='black')
plt.title('Distribution of Current Floor Numbers in Bangalore')
plt.xlabel('Current Floor')
plt.ylabel('Number of Listings')
plt.grid(True)
plt.show()

# %%
bangalore_df_furnishing = bangalore_df[bangalore_df['Furnishing'] != -1]

# %%
bangalore_df_furnishing_copy = bangalore_df_furnishing.copy()

# Map the Furnishing codes to labels
furnishing_map = {
    0: 'Unfurnished',
    1: 'Semi-Furnished',
    2: 'Furnished'
}
bangalore_df_furnishing_copy['Furnishing'] = bangalore_df_furnishing_copy['Furnishing'].map(furnishing_map)

# %%
plt.figure(figsize=(10, 6))
sns.boxenplot(data=bangalore_df_furnishing_copy, x='Furnishing', y='Price (in lakhs)')
plt.title('Property Price Distribution by Furnishing Type (Boxen Plot)')
plt.xlabel('Furnishing Type')
plt.ylabel('Price (in lakhs)')

plt.show()

# %%
# Plot using FacetGrid
plt.figure(figsize=(10, 6))
g = sns.FacetGrid(bangalore_df_furnishing_copy, col="Furnishing", col_wrap=3, height=4)
g.map(sns.histplot, "Price (in lakhs)", bins=30, kde=True)
g.set_titles("{col_name}")
g.fig.subplots_adjust(top=0.9)
plt.xlim(0,150)
g.fig.suptitle("Price Distribution per Furnishing Type (Price ≤ 200 lakhs)", fontsize=9)
plt.show()

# %%
bangalore_df.groupby('Furnishing')['Price (in lakhs)'].describe()
# Out:
#               count       mean        std   min   25%   50%    75%    max
# Furnishing
# -1            171.0  78.626316  36.109649  15.0  52.0  70.0  99.35  190.0
#  0           8712.0  84.711421  23.530084   8.0  70.0  83.0  88.00  199.0
#  1          11505.0  81.616880  22.854703  20.0  65.0  85.0  90.00  195.0
#  2            977.0  79.916070  21.096822  15.0  78.0  78.0  78.00  195.0

# %%
facing_map = {
    0: "N", 45: "NE", 90: "E", 135: "SE",
    180: "S", 225: "SW", 270: "W", 315: "NW"
}
bangalore_df_facing = bangalore_df.copy()
bangalore_df_facing['facing label'] = bangalore_df['facing'].map(facing_map)

# %%
plt.figure(figsize=(14, 6))
sns.violinplot(
    data=bangalore_df_facing,
    x='facing label',
    y='Price (in lakhs)',
    hue='facing',  # assign x variable to hue
    legend=False,
    palette='pastel',
    density_norm='width',  # replaces 'scale'
    inner='quartile'
)
plt.grid(True)
plt.title('Price Distribution by Facing Direction')
plt.xlabel('Facing Direction')
plt.ylabel('Price (in lakhs)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
bangalore_df.groupby('facing')['Price (in lakhs)'].describe()
# Out:
#           count       mean        std   min    25%   50%     75%    max
# facing
# -1      11151.0  84.244238  24.627899   8.0  70.00  85.0   96.00  195.0
#  0       3045.0  77.253300  13.971858  18.5  64.00  75.0   88.00  198.0
#  45        99.0  88.656566  45.446904  19.5  60.00  75.0  112.50  195.0
#  90      6139.0  82.855221  23.627487  20.0  63.00  85.0   88.00  195.0
#  135       10.0  87.000000  30.404678  46.0  67.25  81.0  104.50  135.0
#  180       29.0  84.344828  41.492061  28.0  53.00  75.0  104.00  175.0
#  225      712.0  78.281601   6.766425  25.0  78.00  78.0   78.00  179.0
#  270      162.0  96.546296  40.226035  25.0  65.00  89.5  125.00  199.0
#  315       18.0  98.288889  49.290279  45.0  59.50  85.0  113.75  198.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.boxplot(data=bangalore_df, x='Balcony', y='Price (in lakhs)', hue='Balcony', palette='Set3', legend=False)
plt.title('Property Price vs Number of Balconies (Bangalore)', fontsize=14)
plt.xlabel('Number of Balconies')
plt.ylabel('Price (in lakhs)')
plt.show()

# %%
bangalore_df.groupby('Balcony')['Price (in lakhs)'].describe()
# Out:
#           count        mean        std    min    25%    50%     75%    max
# Balcony
# 0        9599.0   86.731107  25.235890   15.0   80.0   88.0   97.20  194.0
# 1        4720.0   81.530169  25.289814    8.0   65.0   72.0   86.30  199.0
# 2        5457.0   81.765805  15.126348   10.0   78.0   83.0   88.00  198.0
# 3        1566.0   65.349106  17.309925   35.0   60.0   63.0   63.00  195.0
# 4          18.0  111.011111  41.531588   48.0   84.0   96.6  146.25  195.0
# 5           3.0  152.000000  32.078030  132.0  133.5  135.0  162.00  189.0
# 6           2.0   95.000000   7.071068   90.0   92.5   95.0   97.50  100.0

# %%
bangalore_df_bathroom = bangalore_df[(bangalore_df['Bathroom'] < 5) & (bangalore_df['Bathroom'] !=0)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(
    data=bangalore_df_bathroom,
    x='Bathroom',
    y='Price (in lakhs)',
    hue='Bathroom',             # Explicitly assign hue to avoid warning
    palette='Set3',
    legend=False                # Remove extra legend if not needed
)

plt.title('Property Price vs Number of Bathrooms (Bangalore)', fontsize=14)
plt.xlabel('Number of Bathrooms')
plt.ylabel('Price (in lakhs)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    data=bangalore_df_bathroom,
    x='Bathroom',
    y='Price (in lakhs)',
    hue='Bathroom',
    palette='coolwarm',
    legend=False
)
plt.title('Average Property Price by Number of Bathrooms')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Average Price (in lakhs)')
plt.tight_layout()
plt.show()

# %%
bangalore_df.groupby('Bathroom')['Price (in lakhs)'].describe()
# Out:
#             count        mean        std    min    25%    50%    75%    max
# Bathroom
# 0            11.0  112.181818  53.409397   22.0   77.5  150.0  150.0  170.0
# 1           131.0   50.114504  28.364732   15.0   28.5   45.0   62.0  160.0
# 2         16417.0   81.130334  20.939358    8.0   65.0   85.0   88.0  195.0
# 3          4073.0   81.804788  23.771376   10.0   63.0   78.0   90.0  199.0
# 4           725.0  130.543448   6.221940   83.0  130.0  130.0  130.0  198.0
# 5             3.0  143.333333  29.297326  110.0  132.5  155.0  160.0  165.0
# 6             2.0  140.000000   7.071068  135.0  137.5  140.0  142.5  145.0
# 7             1.0   62.000000        NaN   62.0   62.0   62.0   62.0   62.0
# 8             1.0   18.600000        NaN   18.6   18.6   18.6   18.6   18.6
# 9             1.0  190.000000        NaN  190.0  190.0  190.0  190.0  190.0

# %%
bangalore_df_BHK = bangalore_df[bangalore_df['BHK'] < 5]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.barplot(data=bangalore_df_BHK, x='BHK', y='Price (in lakhs)', estimator='mean', palette='coolwarm',legend=False,hue = 'BHK')
plt.title('Average Property Price by BHK')
plt.ylabel('Average Price (in lakhs)')
plt.xlabel('BHK')
plt.show()

# %%
bangalore_df.groupby('BHK')['Price (in lakhs)'].describe()
# Out:
#         count        mean        std    min     25%    50%     75%    max
# BHK
# 1.0      99.0   48.347475  22.726081   15.0   29.25   45.0   61.50  120.0
# 2.0   14701.0   80.796749  21.722634    8.0   65.00   85.0   90.00  190.0
# 3.0    6531.0   87.451585  24.957485   32.0   77.05   85.0   90.00  199.0
# 4.0      22.0  145.540909  30.984307   89.9  120.75  146.0  169.50  198.0
# 5.0       2.0  145.000000  49.497475  110.0  127.50  145.0  162.50  180.0
# 6.0       1.0  135.000000        NaN  135.0  135.00  135.0  135.00  135.0
# 7.0       1.0  170.000000        NaN  170.0  170.00  170.0  170.00  170.0
# 8.0       1.0   18.600000        NaN   18.6   18.60   18.6   18.60   18.6
# 9.0       2.0  167.500000  31.819805  145.0  156.25  167.5  178.75  190.0
# 10.0      1.0  185.000000        NaN  185.0  185.00  185.0  185.00  185.0

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(
    x=bangalore_df['Final Carpet Area (in sqft)'],
    y=bangalore_df['Price (in lakhs)'],
    gridsize=50,
    cmap='viridis',
    mincnt=1
)
plt.colorbar(label='Count in Bin')
plt.xlabel('Final Carpet Area (sqft)')
plt.ylabel('Price (in lakhs)')
plt.title('Hexbin Plot: Price vs Final Carpet Area')
plt.xlim(0,3000)
plt.grid(True)
plt.show()

# %%
bangalore_df_parking = bangalore_df[bangalore_df['Car Parking'] != -1]

# %%
bangalore_df.groupby('Car Parking')['Price (in lakhs)'].describe()
# Out:
#                count       mean        std   min   25%   50%   75%    max
# Car Parking
# -1           14179.0  80.981028  21.738781   8.0  70.0  83.0  90.0  195.0
#  0              17.0  62.970588  36.323817  20.0  38.0  55.0  84.0  165.0
#  1            7169.0  86.376161  25.553269  19.9  64.0  85.0  88.0  199.0

# %%
parking_map = {
    0 : 'Open',
    1 : 'Closed'
}
bangalore_df_parking.loc[:, 'Parking'] = bangalore_df_parking['Car Parking'].map(parking_map)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10380\1693691944.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bangalore_df_parking.loc[:, 'Parking'] = bangalore_df_parking['Car Parking'].map(parking_map)

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=bangalore_df_parking, x='Parking', y='Price (in lakhs)', estimator='mean', palette='coolwarm',legend=False,hue = 'Car Parking')
plt.title('Price vs Car Parking')
plt.ylabel('Average Price (in lakhs)')
plt.xlabel('Car Parking')
plt.show()

# %%
# Step 1: Define the mapping
ownership_map = {
    0: 'Freehold',
    1: 'Leasehold',
    2: 'Co-operative Society',
    3: 'Power of Attorney'
    # Add more if needed
}

# Step 2: Create a new column with mapped values
bangalore_df['Ownership Type'] = bangalore_df['Ownership'].map(ownership_map)

plt.figure(figsize=(10, 6))
sns.boxplot(data=bangalore_df, x='Ownership Type', y='Price (in lakhs)', palette='pastel')
plt.title('Price Distribution by Ownership Type')
plt.xlabel('Ownership Type')
plt.ylabel('Price (in lakhs)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10380\3994162282.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=bangalore_df, x='Ownership Type', y='Price (in lakhs)', palette='pastel')

# %%
plt.figure(figsize=(10, 6))
avg_price = bangalore_df.groupby('Ownership Type')['Price (in lakhs)'].mean().sort_values()
sns.barplot(x=avg_price.index, y=avg_price.values, palette='coolwarm')
plt.title('Average Price by Ownership Type')
plt.ylabel('Average Price (in lakhs)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10380\2449276600.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price.index, y=avg_price.values, palette='coolwarm')

# %%
bangalore_df.groupby('Ownership Type')['Price (in lakhs)'].describe()
# Out:
#                         count       mean        std   min   25%   50%    75%  \
# Ownership Type
# Co-operative Society     11.0  80.272727  25.436552  48.0  59.0  85.0   95.0
# Freehold              10175.0  81.173327  21.540771  18.5  65.0  78.0   88.0
# Leasehold                13.0  73.384615  26.781643  32.0  60.0  70.0   89.0
# Power of Attorney        11.0  83.118182  40.228518  37.3  57.5  65.0  110.0
#
#                         max
# Ownership Type
# Co-operative Society  130.0
# Freehold              199.0
# Leasehold             140.0
# Power of Attorney     150.0

# %%
bangalore_df.groupby('Transaction')['Price (in lakhs)'].describe()
# Out:
#                count       mean        std   min     25%   50%     75%    max
# Transaction
# -1               2.0  57.500000  10.606602  50.0  53.750  57.5   61.25   65.0
#  0           17212.0  80.117133  21.127327   8.0  65.000  80.0   88.00  198.0
#  1            4148.0  93.841876  27.908472  18.5  73.275  88.0  117.00  199.0
#  2               3.0  61.333333  33.501244  25.0  46.500  68.0   79.50   91.0

# %%
Transaction_map = {
    0: 'Resale',
    1: 'New Property',
    2: 'Other',
    3: 'Rent'
    # Add more if needed
}

# Step 2: Create a new column with mapped values
bangalore_df['Transaction Type'] = bangalore_df['Transaction'].map(Transaction_map)

plt.figure(figsize=(10, 6))
sns.boxplot(data=bangalore_df, x='Transaction Type', y='Price (in lakhs)', palette='Set2')
plt.title("Price Distribution by Transaction Type")
plt.xlabel("Transaction Type")
plt.ylabel("Price (in lakhs)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10380\90466811.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=bangalore_df, x='Transaction Type', y='Price (in lakhs)', palette='Set2')

# %%
# Set figure size
plt.figure(figsize=(10, 6))

# Create a bar plot of average price per transaction type
sns.barplot(data=bangalore_df, x='Transaction Type', y='Price (in lakhs)', palette='Set2', estimator='mean')

# Add titles and labels
plt.title("Average Price by Transaction Type")
plt.xlabel("Transaction Type")
plt.ylabel("Average Price (in lakhs)")
plt.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10380\3725254594.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bangalore_df, x='Transaction Type', y='Price (in lakhs)', palette='Set2', estimator='mean')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Mapping 0/1 to meaningful labels
feature_map = {0: 'No', 1: 'Yes'}

# Create a copy with labels
bangalore_df_plot = bangalore_df.copy()
bangalore_df_plot['Garden'] = bangalore_df_plot['Garden/Park'].map(feature_map)
bangalore_df_plot['Main Road'] = bangalore_df_plot['Main Road'].map(feature_map)
bangalore_df_plot['Pool'] = bangalore_df_plot['Pool'].map(feature_map)

# Set up subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Garden
sns.boxplot(data=bangalore_df_plot, x='Garden', y='Price (in lakhs)', palette='pastel', legend = False ,ax=axes[0])
axes[0].set_title('Price vs Garden')

# Main Road
sns.boxplot(data=bangalore_df_plot, x='Main Road', y='Price (in lakhs)', palette='Set2', legend = False, ax=axes[1])
axes[1].set_title('Price vs Main Road')

# Pool
sns.boxplot(data=bangalore_df_plot, x='Pool', y='Price (in lakhs)', palette='coolwarm', legend = False ,  ax=axes[2])
axes[2].set_title('Price vs Pool')

# General formatting
for ax in axes:
    ax.set_xlabel('')
    ax.set_ylabel('Price (in lakhs)')

plt.suptitle('Property Price Distribution Based on Amenities', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10380\826832288.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=bangalore_df_plot, x='Garden', y='Price (in lakhs)', palette='pastel', legend = False ,ax=axes[0])
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10380\826832288.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=bangalore_df_plot, x='Main Road', y='Price (in lakhs)', palette='Set2', legend = False, ax=axes[1])
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10380\826832288.py:25: FutureWarning:
#
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
sns.histplot(data=bangalore_df_plot, x='Price (in lakhs)', hue='Garden', element='step', common_norm=False, ax=axes[0])
axes[0].set_title("Price Distribution by Garden")
axes[0].set_xlim(0, 140)
sns.histplot(data=bangalore_df_plot, x='Price (in lakhs)', hue='Main Road', element='step', common_norm=False, ax=axes[1])
axes[1].set_title("Price Distribution by Main Road")
axes[1].set_xlim(0, 140)
sns.histplot(data=bangalore_df_plot, x='Price (in lakhs)', hue='Pool', element='step', common_norm=False, ax=axes[2])
axes[2].set_title("Price Distribution by Pool")
axes[2].set_xlim(0, 140)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.barplot(data=bangalore_df_plot, x='Garden', y='Price (in lakhs)', estimator='mean', ax=axes[0])
axes[0].set_title("Average Price by Garden")

sns.barplot(data=bangalore_df_plot, x='Main Road', y='Price (in lakhs)', estimator='mean', ax=axes[1])
axes[1].set_title("Average Price by Main Road")

sns.barplot(data=bangalore_df_plot, x='Pool', y='Price (in lakhs)', estimator='mean', ax=axes[2])
axes[2].set_title("Average Price by Pool")

plt.tight_layout()
plt.show()
